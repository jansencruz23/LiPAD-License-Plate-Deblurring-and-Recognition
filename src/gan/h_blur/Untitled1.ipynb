# %%
import torch
import paddle
# Out:
# Error: Can not import paddle core while this file exists: D:\User\Jansen\Self Study\2025 - 05 - MAY\LiPAD\lipad-venv\Lib\site-packages\paddle\base\libpaddle.pyd
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 2
#       1 import torch
# ----> 2 import paddle
#
# File D:\User\Jansen\Self Study\2025 - 05 - MAY\LiPAD\lipad-venv\Lib\site-packages\paddle\__init__.py:28
#      21     sys.stderr.write(
#      22         '''Warning with import paddle: you should not
#      23      import paddle from the source directory; please install paddlepaddle*.whl firstly.'''
#      24     )
#      26 # NOTE(SigureMo): We should place the import of base.core before other modules,
#      27 # because there are some initialization codes in base/core/__init__.py.
# ---> 28 from .base import core  # noqa: F401
#      29 from .batch import batch
# ...
