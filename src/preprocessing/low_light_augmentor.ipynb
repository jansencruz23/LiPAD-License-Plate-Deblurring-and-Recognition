# %%
import cv2
import numpy as np
import os
import random
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def apply_low_light(img, brightness=0.3):
    low_light_img = np.clip(img * brightness, 0, 255).astype(np.uint8)
    return low_light_img

# %%
ROOT_DIR = os.path.abspath(os.path.join(os.getcwd(), '..', '..'))
in_path = os.path.join(ROOT_DIR, 'data', 'experiment', 'enhanced')
out_path = os.path.join(ROOT_DIR, 'data', 'experiment', 'low_light enhanced')

# %%
files = os.listdir(in_path)

# %%
for image_name in files:
    img = cv2.imread(os.path.join(in_path, image_name))
    brightness = random.uniform(0.05, 0.25)
    low_light_img = apply_low_light(img, brightness=brightness)
    #print(f'Brightness: {brightness}')

    filename = f'{out_path}/{image_name}'
    cv2.imwrite(filename, low_light_img)
    #print(f'Saved low light plate: {filename}')

    #plt.imshow(cv2.cvtColor(low_light_img, cv2.COLOR_BGR2RGB))
    #plt.axis('off')
    #plt.show()

# %%
import shutil

# %%
def numeric_sort_key(filename):
    return int(os.path.splitext(filename)[0])

# %%
normal_dir = os.path.join(ROOT_DIR, 'data', 'experiment', 'normal')
out_dir = os.path.join(ROOT_DIR, 'data', 'experiment', 'train', 'normal')
normal = [f for f in os.listdir(normal_dir) if f.endswith('.jpg')]
normal = sorted(files, key=lambda x: int(x.replace('.jpg', '')))
normal = normal[:5942]

for image_name in normal:
    src = os.path.join(normal_dir, image_name)
    dst = os.path.join(out_dir, image_name)
    shutil.copy2(src, dst)

# %%
enhanced_dir = os.path.join(ROOT_DIR, 'data', 'experiment', 'enhanced')
out_dir = os.path.join(ROOT_DIR, 'data', 'experiment', 'train', 'normal')
enhanced = [f for f in os.listdir(enhanced_dir) if f.endswith('.jpg')]
enhanced = sorted(files, key=lambda x: int(x.replace('.jpg', '')))
enhanced =
for image_name in enhanced:
    src = os.path.join(enhanced_dir, image_name)
    dst = os.path.join(out_dir, image_name)
    shutil.copy2(src, dst) enhanced[5942:11883]

# %%
# train/normal = experiment/normal/5942 images + experiment/enhanced/5941 images
# train/h_blur = experiment/h_blur cv/2971 images + experiment/h_blur kornia/2971 images + experiment/h_blur cv enhanced/2970 images + experiment/h_blur kornia enhanced/2971 images
# train/v_blur = experiment/v_blur cv/2971 images + experiment/v_blur kornia/2971 images + experiment/v_blur cv enhanced/2970 images + experiment/v_blur kornia enhanced/2971 images
# train/low_light = experiment/low_light/5942 images + experiment/low_light enhanced/5941

# %% [markdown]
# ### H Blur

# %%
h_blur_cv_dir = os.path.join(ROOT_DIR, 'data', 'experiment', 'h_blur cv')
out_dir = os.path.join(ROOT_DIR, 'data', 'experiment', 'train', 'h_blur')
h_blur_cv = [f for f in os.listdir(h_blur_cv_dir) if f.endswith('.jpg')]
h_blur_cv = sorted(files, key=lambda x: int(x.replace('.jpg', '')))
h_blur_cv = h_blur_cv[:2971]

for image_name in h_blur_cv:
    src = os.path.join(h_blur_cv_dir, image_name)
    dst = os.path.join(out_dir, image_name)
    shutil.copy2(src, dst)

# %%
h_blur_kornia_dir = os.path.join(ROOT_DIR, 'data', 'experiment', 'h_blur kornia')
out_dir = os.path.join(ROOT_DIR, 'data', 'experiment', 'train', 'h_blur')
h_blur_kornia = [f for f in os.listdir(h_blur_kornia_dir) if f.endswith('.jpg')]
h_blur_kornia = sorted(files, key=lambda x: int(x.replace('.jpg', '')))
h_blur_kornia = h_blur_kornia[2971:5942]

for image_name in h_blur_kornia:
    src = os.path.join(h_blur_kornia_dir, image_name)
    dst = os.path.join(out_dir, image_name)
    shutil.copy2(src, dst)

# %%
h_blur_cv_en_dir = os.path.join(ROOT_DIR, 'data', 'experiment', 'h_blur cv enhanced')
out_dir = os.path.join(ROOT_DIR, 'data', 'experiment', 'train', 'h_blur')
h_blur_cv_en = [f for f in os.listdir(h_blur_cv_en_dir) if f.endswith('.jpg')]
h_blur_cv_en = sorted(files, key=lambda x: int(x.replace('.jpg', '')))
h_blur_cv_en = h_blur_cv_en[5942:8912]

for image_name in h_blur_cv_en:
    src = os.path.join(h_blur_cv_en_dir, image_name)
    dst = os.path.join(out_dir, image_name)
    shutil.copy2(src, dst)

# %%
h_blur_kornia_en_dir = os.path.join(ROOT_DIR, 'data', 'experiment', 'h_blur kornia enhanced')
out_dir = os.path.join(ROOT_DIR, 'data', 'experiment', 'train', 'h_blur')
h_blur_kornia_en = [f for f in os.listdir(h_blur_kornia_en_dir) if f.endswith('.jpg')]
h_blur_kornia_en = sorted(files, key=lambda x: int(x.replace('.jpg', '')))
h_blur_kornia_en = h_blur_kornia_en[8912:11883]

for image_name in h_blur_kornia_en:
    src = os.path.join(h_blur_kornia_en_dir, image_name)
    dst = os.path.join(out_dir, image_name)
    shutil.copy2(src, dst)

# %% [markdown]
# ### V Blur

# %%
v_blur_cv_dir = os.path.join(ROOT_DIR, 'data', 'experiment', 'v_blur cv')
out_dir = os.path.join(ROOT_DIR, 'data', 'experiment', 'train', 'v_blur')
v_blur_cv = [f for f in os.listdir(v_blur_cv_dir) if f.endswith('.jpg')]
v_blur_cv = sorted(files, key=lambda x: int(x.replace('.jpg', '')))
v_blur_cv = v_blur_cv[:2971]

for image_name in v_blur_cv:
    src = os.path.join(v_blur_cv_dir, image_name)
    dst = os.path.join(out_dir, image_name)
    shutil.copy2(src, dst)

# %%
v_blur_kornia_dir = os.path.join(ROOT_DIR, 'data', 'experiment', 'v_blur kornia')
out_dir = os.path.join(ROOT_DIR, 'data', 'experiment', 'train', 'v_blur')
v_blur_kornia = [f for f in os.listdir(v_blur_kornia_dir) if f.endswith('.jpg')]
v_blur_kornia = sorted(files, key=lambda x: int(x.replace('.jpg', '')))
v_blur_kornia = v_blur_kornia[2971:5942]

for image_name in v_blur_kornia:
    src = os.path.join(v_blur_kornia_dir, image_name)
    dst = os.path.join(out_dir, image_name)
    shutil.copy2(src, dst)

# %%
v_blur_cv_en_dir = os.path.join(ROOT_DIR, 'data', 'experiment', 'v_blur cv enhanced')
out_dir = os.path.join(ROOT_DIR, 'data', 'experiment', 'train', 'v_blur')
v_blur_cv_en = [f for f in os.listdir(v_blur_cv_en_dir) if f.endswith('.jpg')]
v_blur_cv_en = sorted(files, key=lambda x: int(x.replace('.jpg', '')))
v_blur_cv_en = v_blur_cv_en[5942:8912]

for image_name in v_blur_cv_en:
    src = os.path.join(v_blur_cv_en_dir, image_name)
    dst = os.path.join(out_dir, image_name)
    shutil.copy2(src, dst)

# %%
v_blur_kornia_en_dir = os.path.join(ROOT_DIR, 'data', 'experiment', 'v_blur kornia enhanced')
out_dir = os.path.join(ROOT_DIR, 'data', 'experiment', 'train', 'v_blur')
v_blur_kornia_en = [f for f in os.listdir(v_blur_kornia_en_dir) if f.endswith('.jpg')]
v_blur_kornia_en = sorted(files, key=lambda x: int(x.replace('.jpg', '')))
v_blur_kornia_en = v_blur_kornia_en[8912:11883]

for image_name in v_blur_kornia_en:
    src = os.path.join(v_blur_kornia_en_dir, image_name)
    dst = os.path.join(out_dir, image_name)
    shutil.copy2(src, dst)

# %% [markdown]
# ### Low Light

# %%
low_light_dir = os.path.join(ROOT_DIR, 'data', 'experiment', 'low_light')
out_dir = os.path.join(ROOT_DIR, 'data', 'experiment', 'train', 'low_light')
low_light = [f for f in os.listdir(low_light_dir) if f.endswith('.jpg')]
low_light = sorted(files, key=lambda x: int(x.replace('.jpg', '')))
low_light = low_light[:5942]

for image_name in low_light:
    src = os.path.join(low_light_dir, image_name)
    dst = os.path.join(out_dir, image_name)
    shutil.copy2(src, dst)

# %%
low_light_enhanced_dir = os.path.join(ROOT_DIR, 'data', 'experiment', 'low_light enhanced')
out_dir = os.path.join(ROOT_DIR, 'data', 'experiment', 'train', 'low_light')
low_light_en = [f for f in os.listdir(low_light_enhanced_dir) if f.endswith('.jpg')]
low_light_en = sorted(files, key=lambda x: int(x.replace('.jpg', '')))
low_light_en = low_light_en[5942:11883]

for image_name in low_light_en:
    src = os.path.join(low_light_enhanced_dir, image_name)
    dst = os.path.join(out_dir, image_name)
    shutil.copy2(src, dst)
