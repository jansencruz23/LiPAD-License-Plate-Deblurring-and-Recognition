# %% [markdown]
# # Normal image stats

# %%
import os
import cv2
import numpy as np
from tqdm import tqdm

# %%
# Set your image folder path (e.g., normal images)
ROOT_DIR = os.path.abspath(os.path.join(os.getcwd(), '..', '..'))
DATA_DIR = os.path.join(ROOT_DIR, 'data')
image_dir = os.path.join(DATA_DIR, 'train', 'normal')
image_files = [f for f in os.listdir(image_dir) if f.endswith('.jpg')]

# %%
# Accumulators
means = []
stds = []

# %%
for file in tqdm(image_files, desc='Processing images'):
    img = cv2.imread(os.path.join(image_dir, file))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = img / 255.0 # normalize to [0, 1]

    means.append(np.mean(img, axis=(0,1)))
    stds.append(np.std(img, axis=(0,1)))
# Out:
# Processing images: 100%|████████████████████████████████████████████████████████| 11883/11883 [01:13<00:00, 161.91it/s]

# %%
# Convert to numpy
means = np.array(means)
stds = np.array(stds)

# %%
# Average across all images
mean_rgb = np.mean(means, axis=0)
std_rgb = np.mean(stds, axis=0)

# %%
print("Mean (R, G, B):", mean_rgb)
print("Std  (R, G, B):", std_rgb)
# Out:
# Mean (R, G, B): [0.46668784 0.47452078 0.48279296]
# Std  (R, G, B): [0.23489688 0.24030472 0.23554797]

# %%
Mean (R, G, B): [0.46647524 0.47408519 0.48169253]
Std  (R, G, B): [0.23569164 0.24072543 0.23566305]

# %% [markdown]
# # Low light image stats

# %%
# Set your image folder path (e.g., normal images)
ROOT_DIR = os.path.abspath(os.path.join(os.getcwd(), '..', '..'))
DATA_DIR = os.path.join(ROOT_DIR, 'data')
image_dir = os.path.join(DATA_DIR, 'train', 'low_light')
image_files = [f for f in os.listdir(image_dir) if f.endswith('.jpg')]

# %%
# Accumulators
means = []
stds = []

# %%
for file in tqdm(image_files, desc='Processing images'):
    img = cv2.imread(os.path.join(image_dir, file))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = img / 255.0 # normalize to [0, 1]

    means.append(np.mean(img, axis=(0,1)))
    stds.append(np.std(img, axis=(0,1)))
# Out:
# Processing images: 100%|████████████████████████████████████████████████████████| 11883/11883 [00:30<00:00, 390.24it/s]

# %%
# Convert to numpy
means = np.array(means)
stds = np.array(stds)

# %%
# Average across all images
mean_rgb = np.mean(means, axis=0)
std_rgb = np.mean(stds, axis=0)

# %%
print("Mean (R, G, B):", mean_rgb)
print("Std  (R, G, B):", std_rgb)
# Out:
# Mean (R, G, B): [0.06806663 0.06942986 0.07024706]
# Std  (R, G, B): [0.03520789 0.03602721 0.03545172]
